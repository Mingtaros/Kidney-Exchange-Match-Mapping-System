# %%
import numpy as np
import pandas as pd

# %%
simple_mip = pd.read_csv("../data/K=3 L=5/SimpleMIP.tsv", sep='\t')
simple_mip.head()
# Out:
#   Seed   Nb Nodes   Nb altruists   Nb pairs   Nb arcs   Nb arcs PRA80   \
# 0     0         20              1         19        72               2
# 1     1         20              1         19        70               1
# 2     2         20              1         19        82               5
# 3     3         20              2         18       106               3
# 4     4         20              0         20       127               0
#
#    Nb Cycles  Nb Chains   Nb Cycles and Chains  Max node fail   ...  \
# 0           6         23                     29              1  ...
# 1          13          0                     13              1  ...
# 2          37          1                     38              1  ...
# 3          13        376                    389              1  ...
# 4         113          0                    113              1  ...
#
#    Nb matches RE   Nb PRA80 det   Nb PRA80 RE  Nb transplants det   \
# ...
