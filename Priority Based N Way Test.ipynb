# %%
import numpy as np
import pandas as pd

from algorithm.util.directed_graph import DirectedGraph
from algorithm.util.read_pairs_data import read_pairs_db
from algorithm.util.graph_vis import GraphVisualization
from algorithm.priority_based_n_way import PriorityBasedNWay

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import time

# %%
pairs = read_pairs_db(0, 99)
pairs.head()
# Out:
#   pair_num donor_bloodtype recipient_bloodtype  pra
# 0       P0               A                   O   90
# 1       P1               B                   A    5
# 2       P2               A                   O   90
# 3       P3               A                   A   92
# 4       P4               A                   B    5

# %%
grph = DirectedGraph(pairs)

# %%
a = time.time()
cycles = grph.get_cycles()
b = time.time() - a
print(b, "s")
# Out:
# 0.008976221084594727 s

# %%
cycles
# Out:
# [['P1', 'P4'],
#  ['P1', 'P4', 'P3'],
#  ['P4', 'P3', 'P5'],
#  ['P1', 'P4', 'P3', 'P5', 'P19'],
#  ['P3', 'P5', 'P19'],
#  ['P5', 'P19'],
#  ['P4', 'P3', 'P5', 'P19', 'P11'],
#  ['P19', 'P11'],
#  ['P1', 'P4', 'P3', 'P5', 'P19', 'P11', 'P27'],
#  ['P3', 'P5', 'P19', 'P11', 'P27'],
#  ['P5', 'P19', 'P11', 'P27'],
#  ['P11', 'P27'],
#  ['P1', 'P4', 'P3', 'P5', 'P19', 'P11', 'P27', 'P15'],
#  ['P3', 'P5', 'P19', 'P11', 'P27', 'P15'],
#  ['P5', 'P19', 'P11', 'P27', 'P15'],
#  ['P11', 'P27', 'P15'],
#  ['P4', 'P3', 'P5', 'P19', 'P11', 'P27', 'P15', 'P17'],
#  ['P19', 'P11', 'P27', 'P15', 'P17'],
#  ['P27', 'P15', 'P17'],
#  ['P1', 'P4', 'P3', 'P5', 'P19', 'P11', 'P27', 'P15', 'P17', 'P36'],
#  ['P3', 'P5', 'P19', 'P11', 'P27', 'P15', 'P17', 'P36'],
#  ['P5', 'P19', 'P11', 'P27', 'P15', 'P17', 'P36'],
#  ['P11', 'P27', 'P15', 'P17', 'P36'],
#  ['P15', 'P17', 'P36'],
#  ['P17', 'P36'],
#  ['P4', 'P3', 'P5', 'P19', 'P11', 'P27', 'P15', 'P17', 'P36', 'P21', 'P39'],
# ...

# %%
pbnway = PriorityBasedNWay(5, 'maximum')

# %%
a = time.time()
pbnway.finalize_exchange(grph)
b = time.time() - a
print(b, "s")
# Out:
# 0.01296854019165039 s

# %%
def display_all(list_of_pairs):
    for p in list_of_pairs:
        display(pairs[pairs['pair_num'] == p])

# %%
flatten = lambda t: [item for sublist in t for item in sublist]
display_all([i for i in grph.medical_data['pair_num'] if (i not in flatten(pbnway.cycles))])
# Out:
#   pair_num donor_bloodtype recipient_bloodtype  pra
# 0       P0               A                   O   90
#   pair_num donor_bloodtype recipient_bloodtype  pra
# 3       P3               A                   A   92
#   pair_num donor_bloodtype recipient_bloodtype  pra
# 8       P8               A                   O    5
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 12      P12               A                   O    5
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 13      P13               B                   O    5
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 15      P15               A                   A   92
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 16      P16               A                   O   28
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 17      P17               B                   A    5
#    pair_num donor_bloodtype recipient_bloodtype  pra
# 20      P20               A                   O    5
# ...

# %%
pbnway.show_donation_mapping()
# Out:
# P36 --> P21 --> P39
# P31 --> P95
# P1 --> P4
# P5 --> P19
# P11 --> P27
# P32 --> P52
# P66 --> P47
# P55 --> P81
# P41 --> P28 --> P29
# P69 --> P49 --> P7
# P54 --> P6
# P60 --> P9
# P85 --> P10
# P44 --> P2
# P14 --> P18
# P40 --> P43
# P59 --> P63

# %%
plt.figure(figsize=(10, 10))
pbnway.show_donation_mapping('graph')

# %%
pbnway.get_num_of_matched_pairs()
# Out:
# 37
